# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\srishti budholia\Downloads\global.xlsx')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df=pd.read_excel(r'C:\Users\srishti budholia\Downloads\global.xlsx')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.shape
# Out:
# (181691, 44)

# %%
df.drop_duplicates()
# Out:
#              eventid  iyear  imonth  iday  extended         country_txt  \
# 0       197000000001   1970       7     2         0  Dominican Republic
# 1       197000000002   1970       0     0         0              Mexico
# 2       197001000001   1970       1     0         0         Philippines
# 3       197001000002   1970       1     0         0              Greece
# 4       197001000003   1970       1     0         0               Japan
# ...              ...    ...     ...   ...       ...                 ...
# 181686  201712310022   2017      12    31         0             Somalia
# 181687  201712310029   2017      12    31         0               Syria
# 181688  201712310030   2017      12    31         0         Philippines
# 181689  201712310031   2017      12    31         0               India
# 181690  201712310032   2017      12    31         0         Philippines
#
#                          region_txt        provstate           city  vicinity  \
# ...

# %%
df.shape
# Out:
# (181691, 44)

# %%
df.isnull().sum()
# Out:
# eventid                 0
# iyear                   0
# imonth                  0
# iday                    0
# extended                0
# country_txt             0
# region_txt              0
# provstate             421
# city                  435
# vicinity                0
# crit1                   0
# crit2                   0
# crit3                   0
# multiple                1
# success                 0
# suicide                 0
# attacktype1_txt         0
# targtype1               0
# targtype1_txt           0
# corp1               42552
# target1               638
# natlty1              1559
# natlty1_txt          1559
# gname                   0
# individual              0
# nperps              71115
# nperpcap            69489
# claimed             66120
# claimmode_txt      162608
# weaptype1_txt           0
# weapdetail          67670
# nkill               10313
# nkillus             64446
# nkillter            66958
# nwound              16311
# ...
